# %%
import numpy as np
import xarray as xr
import rioxarray as rxr
from rioxarray.merge import merge_arrays
from scipy import stats
import matplotlib.pyplot as plt

# %%
ds=xr.open_dataset('/projekt1/ag_maahn/data_obs_nobackup/modis/MCD06COSP_D3/Amazon_cropped/2004/MCD06COSP_D3_MODIS.A2004361.062.2022125044619.nc')
ds
# Out:
# <xarray.Dataset> Size: 560B
# Dimensions:    (latitude: 30, longitude: 40)
# Coordinates:
#   * latitude   (latitude) float64 240B -19.5 -18.5 -17.5 -16.5 ... 7.5 8.5 9.5
#   * longitude  (longitude) float64 320B -79.5 -78.5 -77.5 ... -42.5 -41.5 -40.5
# Data variables:
#     *empty*
# Attributes: (12/51)
#     YAML_config:                       grid_settings:\n  gridsize: 1\n  proje...
#     Yori_version:                      1.5.0
#     input_files:                       MCD06COSP_G3_MODIS_Aqua.A2004361.0000....
#     daily_defn_of_day_adjustment:      False
#     history:
#     source:                            idl 8.4, mcd06cosp_preyori 20220218-1,...
#     ...                                ...
#     longitude_resolution:              1.0
#     license:                           http://science.nasa.gov/earth-science/...
#     stdname_vocabulary:                NetCDF Climate and Forecast (CF) Metad...
# ...

# %%
import netCDF4 as nc

ds = nc.Dataset('/projekt1/ag_maahn/data_obs_nobackup/modis/MCD06COSP_D3/2004/MCD06COSP_D3_MODIS.A2004361.062.2022125044619.nc')
print(ds.groups.keys())
# Out:
# dict_keys(['Solar_Zenith', 'Solar_Azimuth', 'Sensor_Zenith', 'Sensor_Azimuth', 'Cloud_Top_Pressure', 'Cloud_Mask_Fraction', 'Cloud_Mask_Fraction_Low', 'Cloud_Mask_Fraction_Mid', 'Cloud_Mask_Fraction_High', 'Cloud_Optical_Thickness_Liquid', 'Cloud_Optical_Thickness_Ice', 'Cloud_Optical_Thickness_Total', 'Cloud_Optical_Thickness_PCL_Liquid', 'Cloud_Optical_Thickness_PCL_Ice', 'Cloud_Optical_Thickness_PCL_Total', 'Cloud_Optical_Thickness_Log10_Liquid', 'Cloud_Optical_Thickness_Log10_Ice', 'Cloud_Optical_Thickness_Log10_Total', 'Cloud_Particle_Size_Liquid', 'Cloud_Particle_Size_Ice', 'Cloud_Particle_Size_PCL_Liquid', 'Cloud_Particle_Size_PCL_Ice', 'Cloud_Water_Path_Liquid', 'Cloud_Water_Path_Ice', 'Cloud_Water_Path_PCL_Liquid', 'Cloud_Water_Path_PCL_Ice', 'Cloud_Retrieval_Fraction_Liquid', 'Cloud_Retrieval_Fraction_Ice', 'Cloud_Retrieval_Fraction_Total', 'Cloud_Retrieval_Fraction_PCL_Liquid', 'Cloud_Retrieval_Fraction_PCL_Ice', 'Cloud_Retrieval_Fraction_PCL_Total'])

# %%
for group_name in ['Cloud_Mask_Fraction', 'Cloud_Optical_Thickness_Total']:
    group = ds.groups[group_name]
    print(f"\n{group_name}: {list(group.variables.keys())}")
# Out:
# Cloud_Mask_Fraction: ['Mean', 'Standard_Deviation', 'Sum', 'Pixel_Counts', 'Sum_Squares']
#
# Cloud_Optical_Thickness_Total: ['Mean', 'Standard_Deviation', 'Sum', 'Pixel_Counts', 'Sum_Squares', 'JHisto_vs_Cloud_Top_Pressure']

# %%
ds2=xr.open_dataset('/projekt1/ag_maahn/data_obs_nobackup/modis/MCD06COSP_D3/merged/CMF_low.nc')
ds2
# Out:
# <xarray.Dataset> Size: 345MB
# Dimensions:             (time: 8621, longitude: 50, latitude: 20)
# Coordinates:
#   * time                (time) datetime64[ns] 69kB 2002-07-04 ... 2026-03-11
# Dimensions without coordinates: longitude, latitude
# Data variables:
#     Mean                (time, longitude, latitude) float64 69MB ...
#     Standard_Deviation  (time, longitude, latitude) float64 69MB ...
#     Sum                 (time, longitude, latitude) float64 69MB ...
#     Pixel_Counts        (time, longitude, latitude) float64 69MB ...
#     Sum_Squares         (time, longitude, latitude) float64 69MB ...
# Attributes:
#     long_name:     Cloud Fraction from Cloud Mask (Low Clouds, CTP GE 680 hPa...
#     units:         none
#     _FillValue:    -999.0
#     valid_min:     0.0
#     valid_max:     1.0
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
ds_m=ds2.mean(dim='latitude')
ds_mean=ds_m.mean(dim='longitude')
ds_mean
# Out:
# <xarray.Dataset> Size: 414kB
# Dimensions:             (time: 8621)
# Coordinates:
#   * time                (time) datetime64[ns] 69kB 2002-07-04 ... 2026-03-11
# Data variables:
#     Mean                (time) float64 69kB 0.3534 0.3698 ... 0.2585 0.2496
#     Standard_Deviation  (time) float64 69kB 0.2488 0.2733 0.2718 ... 0.24 0.2896
#     Sum                 (time) float64 69kB 206.3 152.6 182.0 ... 95.84 122.8
#     Pixel_Counts        (time) float64 69kB 492.2 490.7 489.3 ... 371.6 486.3
#     Sum_Squares         (time) float64 69kB 187.5 130.6 162.2 ... 84.72 108.3
# Attributes:
#     long_name:     Cloud Fraction from Cloud Mask (Low Clouds, CTP GE 680 hPa...
#     units:         none
#     _FillValue:    -999.0
#     valid_min:     0.0
#     valid_max:     1.0
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
ds_mean['Mean'].plot()

# %%
ds_mean.time[ds_mean['Mean'].isnull()].values
# Out:
# array(['2025-05-12T00:00:00.000000000', '2025-10-24T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
ds_rm = ds_mean.rolling(time=28, center=True).mean()

# %%
da_filled = ds_mean['Mean'].interpolate_na(dim='time')
y = da_filled.values
x = np.arange(len(ds_mean.Mean))


slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
trend = slope * x + intercept

# %%
print(slope)
# Out:
# -8.640808412290469e-07

# %%
plt.figure(figsize=(16, 9))
plt.plot(ds_rm.time, ds_mean.Mean, label='CMF_low')
plt.plot(ds_rm.time, trend, label=f'Trend: {3650*slope:.4f}/decade', color='red')
plt.legend()
plt.show()
print(f'R²={r_value**2}')
print(f'P={p_value}')
# Out:
# R²=0.0011717737244427168
# P=0.0014787935790678418
